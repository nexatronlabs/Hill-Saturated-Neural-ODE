# %% [markdown]
# <a href="https://colab.research.google.com/github/nexatronlabs/Hill-Saturated-Neural-ODE/blob/main/notebooks/nxl_2026_01_neural_ode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchdiffeq matplotlib numpy git+https://github.com/nexatronlabs/Hill-Saturated-Neural-ODE.git
# Out:
# ...
#   Cloning https://github.com/nexatronlabs/Hill-Saturated-Neural-ODE.git to /tmp/pip-req-build-rwik2mxe
#   Running command git clone --filter=blob:none --quiet https://github.com/nexatronlabs/Hill-Saturated-Neural-ODE.git /tmp/pip-req-build-rwik2mxe
#   Resolved https://github.com/nexatronlabs/Hill-Saturated-Neural-ODE.git to commit 1a56eb51a98f1e370035ab7ef5169c74e1787716
#   Preparing metadata (setup.py) ... done
# ...

# %%
import torch
from nexatron import SurgicalHillSaturation

saturation = SurgicalHillSaturation(phi_init=0.10)
print("✅ Nexatron package successfully loaded! Phi:", saturation.phi.item())
# Out:
# ✅ Nexatron package successfully loaded! Phi: 0.7444067001342773

# %%
# !python -c "import urllib.request; urllib.request.urlretrieve('https://raw.githubusercontent.com/nexatronlabs/Hill-Saturated-Neural-ODE/main/benchmark_torchdiffeq.py', 'bench.py')"
# !python bench.py
# Out:
# [System Info] Running benchmark on device: cpu
#
# ...
# Executing Experiment: Standard Vanilla Neural ODE
# ...
# Epoch 01/100 | Loss: 4.879835 | NFE:   26 | Time: 1962.4ms
# Epoch 10/100 | Loss: 2.238256 | NFE:  200 | Time: 1743.8ms
# Epoch 20/100 | Loss: 2.167042 | NFE:  182 | Time: 2780.8ms
# Epoch 30/100 | Loss: 1.818206 | NFE:  158 | Time: 1734.0ms
# Epoch 40/100 | Loss: 1.998047 | NFE:  194 | Time: 2194.0ms
# Epoch 50/100 | Loss: 1.909788 | NFE:  260 | Time: 1793.6ms
# Epoch 60/100 | Loss: 1.888611 | NFE:  272 | Time: 2261.3ms
# Epoch 70/100 | Loss: 1.839592 | NFE:  284 | Time: 1795.4ms
# Epoch 80/100 | Loss: 1.700615 | NFE:  254 | Time: 2211.6ms
# Epoch 90/100 | Loss: 1.887301 | NFE:  278 | Time: 1799.7ms
# Epoch 100/100 | Loss: 1.871021 | NFE:  296 | Time: 2248.4ms
# ------------------------------------------------------------
# Completed in: 197.61s | Mean NFE: 228.7
#
# ...
# Executing Experiment: Surgical Hill-Kinetics Neural ODE (Proposed)
# ...
